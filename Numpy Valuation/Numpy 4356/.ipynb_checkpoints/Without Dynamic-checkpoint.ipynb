# %%
from PIL import Image

# %%
import numpy as np

# %%
im = np.array(Image.open('123.jpg'))
im_shape = im.shape
print("Before trimming:",im.shape)
# Out:
# Before trimming: (640, 640, 3)

# %%
im_trim = im[70:570, 70:570]
print("After trimming:",im_trim.shape)
# Out:
# After trimming: (500, 500, 3)

# %%
a = (im_shape[0]/2)-250
a
# Out:
# 70.0

# %%
Image.fromarray(im_trim).save('trim_123.jpg')

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
t_image = image.imread('trim_123.jpg')

# %%
pyplot.imshow(t_image)
pyplot.show()
